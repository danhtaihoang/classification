# %% [markdown]
# ## Data cleaning
#
# In this section, we first see the data structure and identify data attributes. We then clean the data, including removing bad rows, bad attributes, imputing missing values, etc.
#
# First of all, we import the necessary packages to the Jupyter notebook:

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1)

# %% [markdown]
# We load the raw data.

# %%
df = pd.read_csv('mental.csv',sep= ',')

# %%
df.head()
# Out:
#    id  school_year  semester   age gender  height  weight  phq1  phq2  phq3  \
# 0  A1            1         1  19.0      m    1.50    75.0   2.0   1.0   1.0
# 1  B2            1         1  18.0      m    1.68    56.0   2.0   0.0   1.0
# 2  C3            1         1  19.0      m    1.74    76.0   1.0   1.0   0.0
# 3  D4            1         1  18.0      f    1.68    67.0   2.0   2.0   3.0
# 4  E5            1         1  18.0      m    1.80    83.0   0.0   1.0   1.0
#
#    ...  Unnamed: 245  Unnamed: 246  Unnamed: 247  Unnamed: 248  Unnamed: 249  \
# 0  ...           NaN           NaN           NaN           NaN           NaN
# 1  ...           NaN           NaN           NaN           NaN           NaN
# 2  ...           NaN           NaN           NaN           NaN           NaN
# 3  ...           NaN           NaN           NaN           NaN           NaN
# 4  ...           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 250  Unnamed: 251  Unnamed: 252  Unnamed: 253  Unnamed: 254
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 255 columns]

# %% [markdown]
# Dropping the column `id` as it is unrelated to the dependent variable

# %%
df = df.drop(['id','gender','bed_time','wake_up_time','reported_sleep_hours','nap_duration','weekly_study_hours'],axis=1)

# %% [raw]
# The dependent variable is the resultant response to stress: `thoughts_of_dropping_out`.

# %% [markdown]
# Dropping rows in the dependent variable that aren't missing significantly for other variables.

# %%
df = df.drop(df.index[[188,192,197,204,381]])
#df = df.drop(df.index[[188]])
#df = df.drop(df.index[[192]])
#df = df.drop(df.index[[197]])
#df = df.drop(df.index[[204]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 771 entries, 0 to 775
# Columns: 248 entries, school_year to Unnamed: 254
# dtypes: float64(246), int64(2)
# memory usage: 1.5 MB

# %% [markdown]
# To clearn the data, we first replace the empty value by `nan`.

# %%
# replace empty by nan
df = df.replace(r'^\s+$', np.nan, regex=True)
df
# Out:
#      school_year  semester   age  height  weight  phq1  phq2  phq3  phq4  \
# 0              1         1  19.0    1.50    75.0   2.0   1.0   1.0   1.0
# 1              1         1  18.0    1.68    56.0   2.0   0.0   1.0   2.0
# 2              1         1  19.0    1.74    76.0   1.0   1.0   0.0   3.0
# 3              1         1  18.0    1.68    67.0   2.0   2.0   3.0   3.0
# 4              1         1  18.0    1.80    83.0   0.0   1.0   1.0   2.0
# 5              1         1  18.0    1.74    67.0   0.0   0.0   0.0   1.0
# 6              1         1  18.0    1.78    71.0   1.0   0.0   2.0   2.0
# 7              1         1  19.0    1.69    58.5   0.0   0.0   1.0   1.0
# 8              1         1  20.0    1.55    51.0   1.0   1.0   3.0   1.0
# 9              1         1  19.0    1.75    75.0   1.0   1.0   0.0   1.0
# 10             1         1  18.0    1.86    80.0   0.0   0.0   0.0   1.0
# 11             1         1  18.0     NaN    59.0   3.0   1.0   1.0   1.0
# 12             1         1  19.0    1.76    89.0   1.0   0.0   2.0   2.0
# 13             1         1  18.0    1.74    69.0   1.0   1.0   1.0   0.0
# 14             1         1  18.0    1.70    66.0   0.0   0.0   3.0   3.0
# 15             1         1  18.0    1.75    60.0   1.0   1.0   0.0   1.0
# 16             1         1  18.0    1.62    58.0   1.0   1.0   1.0   1.0
# 17             1         1  18.0    1.58    60.0   1.0   1.0   2.0   1.0
# 18             1         1  18.0    1.78    66.0   3.0   1.0   1.0   0.0
# 19             1         1  18.0    1.70    79.0   1.0   0.0   1.0   1.0
# 20             1         1  18.0    1.77    65.0   2.0   1.0   0.0   1.0
# 21             1         1  18.0    1.60    68.0   1.0   2.0   0.0   0.0
# 22             1         1  19.0    1.85    92.0   1.0   2.0   2.0   2.0
# 23             1         1  19.0    1.62    64.0   0.0   1.0   0.0   1.0
# 24             1         1  18.0    1.69    65.0   1.0   1.0   1.0   1.0
# 25             1         1  18.0    1.78    76.0   1.0   0.0   1.0   1.0
# 26             1         1  19.0    1.78    78.5   1.0   2.0   0.0   1.0
# 27             1         1  18.0    1.60    64.0   1.0   1.0   2.0   3.0
# 28             1         1  19.0    1.64    54.0   1.0   0.0   0.0   0.0
# 29             1         1  18.0    1.80    70.0   0.0   0.0   0.0   1.0
# ..           ...       ...   ...     ...     ...   ...   ...   ...   ...
# 746            4         8  22.0    1.54    59.0   1.0   1.0   1.0   1.0
# 747            4         8  22.0    1.65    70.0   1.0   1.0   3.0   1.0
# 748            4         8  23.0    1.76    90.0   1.0   0.0   1.0   1.0
# 749            4         8  22.0    1.80    85.0   1.0   0.0   1.0   1.0
# 750            4         8  22.0    1.65    51.0   1.0   0.0   1.0   2.0
# 751            4         8  24.0    1.57    59.0   1.0   1.0   0.0   1.0
# 752            4         8  22.0    1.75    86.0   2.0   2.0   1.0   1.0
# 753            4         8  22.0    1.59    63.0   3.0   3.0   3.0   3.0
# 754            4         8  22.0    1.69    89.5   1.0   0.0   0.0   0.0
# 755            4         8  22.0    1.74    68.0   1.0   1.0   1.0   1.0
# 756            4         8  23.0    1.80    75.0   0.0   0.0   1.0   0.0
# 757            4         8  24.0    1.70    82.0   2.0   1.0   2.0   2.0
# 758            4         8  23.0    1.66    47.0   1.0   1.0   2.0   1.0
# 759            4         8  24.0    1.76    87.0   1.0   0.0   0.0   1.0
# 760            4         8  23.0    1.54    60.0   2.0   1.0   0.0   1.0
# 761            4         8  22.0    1.54    62.0   1.0   2.0   1.0   2.0
# 762            4         8  22.0    1.83    93.0   1.0   0.0   1.0   1.0
# 763            4         8  21.0    1.83    91.0   2.0   0.0   0.0   1.0
# 764            4         8  22.0    1.65    60.0   1.0   1.0   1.0   1.0
# 765            4         8  23.0    1.79    72.0   1.0   1.0   1.0   1.0
# 766            4         8  22.0    1.63    48.0   0.0   1.0   0.0   0.0
# 767            4         8  23.0    1.65    55.0   1.0   0.0   0.0   1.0
# 768            4         8  22.0    1.68    74.0   2.0   1.0   0.0   0.0
# 769            4         8  23.0    1.77    89.0   1.0   0.0   0.0   0.0
# 770            4         8  22.0    1.73    77.0   0.0   1.0   0.0   1.0
# 771            4         8  24.0    1.57    52.0   3.0   0.0   1.0   1.0
# 772            4         8  22.0    1.80    82.0   1.0   0.0   0.0   1.0
# 773            4         8  22.0    1.73    68.0   1.0   0.0   0.0   1.0
# 774            4         8  22.0    1.58    57.5   2.0   2.0   3.0   3.0
# 775            4         8  22.0    1.76    70.0   1.0   0.0   0.0   1.0
#
#      phq5  ...  Unnamed: 245  Unnamed: 246  Unnamed: 247  Unnamed: 248  \
# 0     2.0  ...           NaN           NaN           NaN           NaN
# 1     1.0  ...           NaN           NaN           NaN           NaN
# 2     1.0  ...           NaN           NaN           NaN           NaN
# 3     3.0  ...           NaN           NaN           NaN           NaN
# 4     1.0  ...           NaN           NaN           NaN           NaN
# 5     1.0  ...           NaN           NaN           NaN           NaN
# 6     0.0  ...           NaN           NaN           NaN           NaN
# 7     0.0  ...           NaN           NaN           NaN           NaN
# 8     2.0  ...           NaN           NaN           NaN           NaN
# 9     2.0  ...           NaN           NaN           NaN           NaN
# 10    0.0  ...           NaN           NaN           NaN           NaN
# 11    0.0  ...           NaN           NaN           NaN           NaN
# 12    2.0  ...           NaN           NaN           NaN           NaN
# 13    1.0  ...           NaN           NaN           NaN           NaN
# 14    1.0  ...           NaN           NaN           NaN           NaN
# 15    1.0  ...           NaN           NaN           NaN           NaN
# 16    1.0  ...           NaN           NaN           NaN           NaN
# 17    1.0  ...           NaN           NaN           NaN           NaN
# 18    1.0  ...           NaN           NaN           NaN           NaN
# 19    1.0  ...           NaN           NaN           NaN           NaN
# 20    0.0  ...           NaN           NaN           NaN           NaN
# 21    2.0  ...           NaN           NaN           NaN           NaN
# 22    1.0  ...           NaN           NaN           NaN           NaN
# 23    1.0  ...           NaN           NaN           NaN           NaN
# 24    NaN  ...           NaN           NaN           NaN           NaN
# 25    1.0  ...           NaN           NaN           NaN           NaN
# 26    0.0  ...           NaN           NaN           NaN           NaN
# 27    1.0  ...           NaN           NaN           NaN           NaN
# 28    0.0  ...           NaN           NaN           NaN           NaN
# 29    0.0  ...           NaN           NaN           NaN           NaN
# ..    ...  ...           ...           ...           ...           ...
# 746   1.0  ...           NaN           NaN           NaN           NaN
# 747   1.0  ...           NaN           NaN           NaN           NaN
# 748   2.0  ...           NaN           NaN           NaN           NaN
# 749   0.0  ...           NaN           NaN           NaN           NaN
# 750   2.0  ...           NaN           NaN           NaN           NaN
# 751   1.0  ...           NaN           NaN           NaN           NaN
# 752   2.0  ...           NaN           NaN           NaN           NaN
# 753   3.0  ...           NaN           NaN           NaN           NaN
# 754   3.0  ...           NaN           NaN           NaN           NaN
# 755   0.0  ...           NaN           NaN           NaN           NaN
# 756   1.0  ...           NaN           NaN           NaN           NaN
# 757   1.0  ...           NaN           NaN           NaN           NaN
# 758   2.0  ...           NaN           NaN           NaN           NaN
# 759   1.0  ...           NaN           NaN           NaN           NaN
# 760   2.0  ...           NaN           NaN           NaN           NaN
# 761   2.0  ...           NaN           NaN           NaN           NaN
# 762   1.0  ...           NaN           NaN           NaN           NaN
# 763   2.0  ...           NaN           NaN           NaN           NaN
# 764   1.0  ...           NaN           NaN           NaN           NaN
# 765   0.0  ...           NaN           NaN           NaN           NaN
# 766   1.0  ...           NaN           NaN           NaN           NaN
# 767   0.0  ...           NaN           NaN           NaN           NaN
# 768   1.0  ...           NaN           NaN           NaN           NaN
# 769   0.0  ...           NaN           NaN           NaN           NaN
# 770   1.0  ...           NaN           NaN           NaN           NaN
# 771   1.0  ...           NaN           NaN           NaN           NaN
# 772   1.0  ...           NaN           NaN           NaN           NaN
# 773   0.0  ...           NaN           NaN           NaN           NaN
# 774   3.0  ...           NaN           NaN           NaN           NaN
# 775   3.0  ...           NaN           NaN           NaN           NaN
#
#      Unnamed: 249  Unnamed: 250  Unnamed: 251  Unnamed: 252  Unnamed: 253  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# 5             NaN           NaN           NaN           NaN           NaN
# 6             NaN           NaN           NaN           NaN           NaN
# 7             NaN           NaN           NaN           NaN           NaN
# 8             NaN           NaN           NaN           NaN           NaN
# 9             NaN           NaN           NaN           NaN           NaN
# 10            NaN           NaN           NaN           NaN           NaN
# 11            NaN           NaN           NaN           NaN           NaN
# 12            NaN           NaN           NaN           NaN           NaN
# 13            NaN           NaN           NaN           NaN           NaN
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 16            NaN           NaN           NaN           NaN           NaN
# 17            NaN           NaN           NaN           NaN           NaN
# 18            NaN           NaN           NaN           NaN           NaN
# 19            NaN           NaN           NaN           NaN           NaN
# 20            NaN           NaN           NaN           NaN           NaN
# 21            NaN           NaN           NaN           NaN           NaN
# 22            NaN           NaN           NaN           NaN           NaN
# 23            NaN           NaN           NaN           NaN           NaN
# 24            NaN           NaN           NaN           NaN           NaN
# 25            NaN           NaN           NaN           NaN           NaN
# 26            NaN           NaN           NaN           NaN           NaN
# 27            NaN           NaN           NaN           NaN           NaN
# 28            NaN           NaN           NaN           NaN           NaN
# 29            NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 746           NaN           NaN           NaN           NaN           NaN
# 747           NaN           NaN           NaN           NaN           NaN
# 748           NaN           NaN           NaN           NaN           NaN
# 749           NaN           NaN           NaN           NaN           NaN
# 750           NaN           NaN           NaN           NaN           NaN
# 751           NaN           NaN           NaN           NaN           NaN
# 752           NaN           NaN           NaN           NaN           NaN
# 753           NaN           NaN           NaN           NaN           NaN
# 754           NaN           NaN           NaN           NaN           NaN
# 755           NaN           NaN           NaN           NaN           NaN
# 756           NaN           NaN           NaN           NaN           NaN
# 757           NaN           NaN           NaN           NaN           NaN
# 758           NaN           NaN           NaN           NaN           NaN
# 759           NaN           NaN           NaN           NaN           NaN
# 760           NaN           NaN           NaN           NaN           NaN
# 761           NaN           NaN           NaN           NaN           NaN
# 762           NaN           NaN           NaN           NaN           NaN
# 763           NaN           NaN           NaN           NaN           NaN
# 764           NaN           NaN           NaN           NaN           NaN
# 765           NaN           NaN           NaN           NaN           NaN
# 766           NaN           NaN           NaN           NaN           NaN
# 767           NaN           NaN           NaN           NaN           NaN
# 768           NaN           NaN           NaN           NaN           NaN
# 769           NaN           NaN           NaN           NaN           NaN
# 770           NaN           NaN           NaN           NaN           NaN
# 771           NaN           NaN           NaN           NaN           NaN
# 772           NaN           NaN           NaN           NaN           NaN
# 773           NaN           NaN           NaN           NaN           NaN
# 774           NaN           NaN           NaN           NaN           NaN
# 775           NaN           NaN           NaN           NaN           NaN
#
#      Unnamed: 254
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# ..            ...
# 746           NaN
# 747           NaN
# 748           NaN
# 749           NaN
# 750           NaN
# 751           NaN
# 752           NaN
# 753           NaN
# 754           NaN
# 755           NaN
# 756           NaN
# 757           NaN
# 758           NaN
# 759           NaN
# 760           NaN
# 761           NaN
# 762           NaN
# 763           NaN
# 764           NaN
# 765           NaN
# 766           NaN
# 767           NaN
# 768           NaN
# 769           NaN
# 770           NaN
# 771           NaN
# 772           NaN
# 773           NaN
# 774           NaN
# 775           NaN
#
# [771 rows x 248 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 771 entries, 0 to 775
# Columns: 248 entries, school_year to Unnamed: 254
# dtypes: float64(246), int64(2)
# memory usage: 1.5 MB

# %% [markdown]
# The data still contain errors, such as `\t`, ` `, `\?`. We will delete `\t` and ` ` and convert `\?` to `np.nan`.

# %%
df = df.replace('\t','',regex=True)
df = df.replace(' ','',regex=True)
df = df.replace('\?','np.nan',regex=True)

# %% [markdown]
# We determine and drop columns with multiple missing variables.

# %%
def remove_bad_columns(df,bad_column_threshold):
    # find bad columns having too many missing values
    n_null = np.array(df.isnull().sum(axis=0))
    bad_col = np.array([]).astype(int)
    for t in range(len(n_null)):
        if n_null[t] > bad_column_threshold:
            bad_col = np.append(bad_col,t)

    #print(bad_col)
    print('number of bad columns:',len(bad_col))

    # delete bad columns
    df = df.drop(df.columns[bad_col],axis=1)
    #df.info()
    return df

# %%
df = remove_bad_columns(df,15)
# Out:
# number of bad columns: 213

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 771 entries, 0 to 775
# Data columns (total 35 columns):
# school_year                      771 non-null int64
# semester                         771 non-null int64
# age                              771 non-null float64
# height                           766 non-null float64
# weight                           767 non-null float64
# phq1                             770 non-null float64
# phq2                             770 non-null float64
# phq3                             770 non-null float64
# phq4                             770 non-null float64
# phq5                             767 non-null float64
# phq6                             770 non-null float64
# phq7                             770 non-null float64
# phq8                             770 non-null float64
# phq9                             770 non-null float64
# thoughts_of_dropping_out         771 non-null float64
# previous_depression_diagnosis    770 non-null float64
# previous_depression_treatment    767 non-null float64
# gad1                             768 non-null float64
# gad2                             767 non-null float64
# gad3                             768 non-null float64
# gad4                             766 non-null float64
# gad5                             768 non-null float64
# gad6                             768 non-null float64
# gad7                             768 non-null float64
# previous_anxiety_diagnosis       767 non-null float64
# previous_anxiety_treatment       769 non-null float64
# epw1                             765 non-null float64
# epw2                             765 non-null float64
# epw3                             765 non-null float64
# epw4                             764 non-null float64
# epw5                             765 non-null float64
# epw6                             764 non-null float64
# epw7                             765 non-null float64
# epw8                             765 non-null float64
# times_week_nap                   759 non-null float64
# dtypes: float64(33), int64(2)
# memory usage: 216.8 KB

# %% [markdown]
# We find bad rows with too many missing values and remove them.

# %%
def remove_bad_rows(df,bad_row_threshold):   
    # find bad rows having too many missing values
    n_null = np.array(df.isnull().sum(axis=1))
    bad_row = np.array([])
    for t in range(len(n_null)):
        if n_null[t] > bad_row_threshold:
            bad_row = np.append(bad_row,t)

    #print(bad_row)
    print('number of bad rows:',len(bad_row))

    # delete bad rows
    df = df.drop(bad_row)
    #df.info()
    return df

# %%
df = remove_bad_rows(df,5)
# Out:
# number of bad rows: 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 775
# Data columns (total 35 columns):
# school_year                      763 non-null int64
# semester                         763 non-null int64
# age                              763 non-null float64
# height                           758 non-null float64
# weight                           759 non-null float64
# phq1                             762 non-null float64
# phq2                             762 non-null float64
# phq3                             762 non-null float64
# phq4                             762 non-null float64
# phq5                             759 non-null float64
# phq6                             762 non-null float64
# phq7                             762 non-null float64
# phq8                             762 non-null float64
# phq9                             762 non-null float64
# thoughts_of_dropping_out         763 non-null float64
# previous_depression_diagnosis    762 non-null float64
# previous_depression_treatment    759 non-null float64
# gad1                             760 non-null float64
# gad2                             759 non-null float64
# gad3                             760 non-null float64
# gad4                             758 non-null float64
# gad5                             760 non-null float64
# gad6                             760 non-null float64
# gad7                             760 non-null float64
# previous_anxiety_diagnosis       759 non-null float64
# previous_anxiety_treatment       761 non-null float64
# epw1                             759 non-null float64
# epw2                             759 non-null float64
# epw3                             759 non-null float64
# epw4                             758 non-null float64
# epw5                             759 non-null float64
# epw6                             758 non-null float64
# epw7                             759 non-null float64
# epw8                             759 non-null float64
# times_week_nap                   752 non-null float64
# dtypes: float64(33), int64(2)
# memory usage: 214.6 KB

# %% [markdown]
# For convenience, we separate independents `X` and dependent `y` from the data.

# %%
X = df.drop('thoughts_of_dropping_out',axis=1)
y = df['thoughts_of_dropping_out']

# %% [markdown]
# We impute the missing value of X at each column by its median value.

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):
    def __init__(self):
        """Impute missing values.
        - Columns of dtype object are imputed with the most frequent value in column.
        - Columns of other types are imputed with mean of column.
        """
    def fit(self, X, y=None):
        self.fill = pd.Series([X[c].value_counts().index[0]
            # numerical --> mean, categorical --> median
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X], index=X.columns)  
                               
            # numerical, categorical --> median                   
            #if X[c].dtype == np.dtype('O') else X[c].median() for c in X], index=X.columns)
        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
X = DataFrameImputer().fit_transform(X)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 775
# Data columns (total 34 columns):
# school_year                      763 non-null int64
# semester                         763 non-null int64
# age                              763 non-null float64
# height                           763 non-null float64
# weight                           763 non-null float64
# phq1                             763 non-null float64
# phq2                             763 non-null float64
# phq3                             763 non-null float64
# phq4                             763 non-null float64
# phq5                             763 non-null float64
# phq6                             763 non-null float64
# phq7                             763 non-null float64
# phq8                             763 non-null float64
# phq9                             763 non-null float64
# previous_depression_diagnosis    763 non-null float64
# previous_depression_treatment    763 non-null float64
# gad1                             763 non-null float64
# gad2                             763 non-null float64
# gad3                             763 non-null float64
# gad4                             763 non-null float64
# gad5                             763 non-null float64
# gad6                             763 non-null float64
# gad7                             763 non-null float64
# previous_anxiety_diagnosis       763 non-null float64
# previous_anxiety_treatment       763 non-null float64
# epw1                             763 non-null float64
# epw2                             763 non-null float64
# epw3                             763 non-null float64
# epw4                             763 non-null float64
# epw5                             763 non-null float64
# epw6                             763 non-null float64
# epw7                             763 non-null float64
# epw8                             763 non-null float64
# times_week_nap                   763 non-null float64
# dtypes: float64(32), int64(2)
# memory usage: 208.6 KB

# %% [markdown]
# Now, the data are completely clean. We convert attributes `X` and target `y` to numpy arrays and save them to files.

# %%
X = np.array(X)
y = np.array(y)
Xy = np.hstack((X,y[:,np.newaxis]))

np.savetxt('mental_cleaned.dat',Xy,fmt='%s')
